# %%
pip install schedule
# Out:
# Requirement already satisfied: schedule in /opt/hostedtoolcache/Python/3.8.18/x64/lib/python3.8/site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in /opt/hostedtoolcache/Python/3.8.18/x64/lib/python3.8/site-packages (5.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install html5lib
# Out:
# Requirement already satisfied: html5lib in /opt/hostedtoolcache/Python/3.8.18/x64/lib/python3.8/site-packages (1.1)
# Requirement already satisfied: six>=1.9 in /opt/hostedtoolcache/Python/3.8.18/x64/lib/python3.8/site-packages (from html5lib) (1.17.0)
# Requirement already satisfied: webencodings in /opt/hostedtoolcache/Python/3.8.18/x64/lib/python3.8/site-packages (from html5lib) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
import datetime
import pytz
import schedule
import time
from datetime import datetime
from io import StringIO
import os

# %%
url = "https://www.zse.co.zw/price-sheet/"

# %%
def get_todays_data():
  response = requests.get(url)
  data = pd.read_html(StringIO(response.text))
  df = pd.DataFrame(data[0])
  df.columns = df.iloc[0]
  df = df[1:]
  df = df.dropna()
  return df

def get_open_price():
  df = get_todays_data()
  open_price = df[['Company Name','Opening Price']].T
  open_price.columns  = open_price.iloc[0]
  open_price = open_price[1:]
  open_price.index.name = 'Date'
  open_price = open_price.rename(index={open_price.index[0]: datetime.now(pytz.timezone('Africa/Harare'))})
  return open_price

def get_close_price():
  df = get_todays_data()
  close_price = df[['Company Name','Closing Price']].T
  close_price.columns  = close_price.iloc[0]
  close_price = close_price[1:]
  close_price.index.name = 'Date'
  close_price = close_price.rename(index={close_price.index[0]: datetime.now(pytz.timezone('Africa/Harare'))})
  return close_price

def get_vol_traded():
  df = get_todays_data()
  vol_traded = df[['Company Name','Total Traded Volume']].T
  vol_traded.columns  = vol_traded.iloc[0]
  vol_traded = vol_traded[1:]
  vol_traded.index.name = 'Date'
  vol_traded = vol_traded.rename(index={vol_traded.index[0]: datetime.now(pytz.timezone('Africa/Harare'))})
  return vol_traded

# %%
#open_price = get_open_price()
#close_price = get_close_price()
#vol_traded = get_vol_traded()

# %%
def save_data(open_price: pd.DataFrame, close_price: pd.DataFrame, vol_traded: pd.DataFrame):
    # Extract the index name (timestamp) from the DataFrames
    #timestamp = open_price.index[0]
    
    # Create the directory path using the timestamp
    #directory_path = f'archive/{timestamp}'
    
    # Create the directory if it doesn't exist
    #os.makedirs(directory_path, exist_ok=True)
    
    # Save the DataFrames to JSON files with the timestamped directory
    open_price.to_json('archive-single-file/open_price.json', orient='split', date_format='iso')
    close_price.to_json('archive-single-file/close_price.json', orient='split', date_format='iso')
    vol_traded.to_json('archive-single-file/vol_traded.json', orient='split', date_format='iso')

# Example usage

# %%
open_json = pd.read_json('archive-single-file/open_price.json', orient = 'split')
close_json = pd.read_json('archive-single-file/close_price.json', orient = 'split')
vol_json = pd.read_json('archive-single-file/vol_traded.json', orient = 'split')

# %%
#this is the code that needs to run everyday
def update_data():
  open_price = pd.concat([open_json, get_open_price()], axis=0) # Update the variables
  close_price = pd.concat([close_json, get_close_price()], axis=0)
  vol_traded = pd.concat([vol_json, get_vol_traded()], axis=0)

  return open_price, close_price, vol_traded
#update_data()[0].to_json('/Users/apple/Desktop/open_price1.json', orient='split', date_format='iso')
save_data(update_data()[0], update_data()[1] , update_data()[2])

# %%
#open_json1 = pd.read_json('/Users/apple/Desktop/open_price1.json', orient = 'split')
#open_json = pd.read_json('/Users/apple/Desktop/open_price.json', orient = 'split')
open_json
# Out:
#             Afdis Distillers Limited  \
# 2024-11-10                     808.0
# 2024-11-11                     808.0
# 2024-11-12                     808.0
# 2024-11-13                     808.0
# 2024-11-14                     808.0
# ...                              ...
# 2025-01-28                     700.0
# 2025-01-29                     700.0
# 2025-01-30                     700.0
# 2025-01-31                     700.0
# 2025-02-03                     700.0
#
#             Amalgamated Regional Trading (Art) Holdings Limited  \
# 2024-11-10                                              62.00
# 2024-11-11                                              62.00
# 2024-11-12                                              62.00
# 2024-11-13                                              62.00
# 2024-11-14                                              62.00
# ...                                                       ...
# 2025-01-28                                              24.15
# 2025-01-29                                              27.05
# 2025-01-30                                              27.05
# 2025-01-31                                              27.05
# 2025-02-03                                              27.05
#
#             Ariston Holdings Limited  \
# 2024-11-10                    7.8200
# 2024-11-11                    7.8200
# 2024-11-12                    7.8000
# 2024-11-13                    7.7486
# 2024-11-14                    7.7683
# ...                              ...
# 2025-01-28                    6.0000
# 2025-01-29                    6.0000
# 2025-01-30                    6.0000
# 2025-01-31                    6.0000
# 2025-02-03                    6.0000
#
#             British American Tobacco Zimbabwe Limited  Cafca Limited  \
# 2024-11-10                                    11995.0       1560.000
# 2024-11-11                                    11995.0       1560.000
# 2024-11-12                                    11900.0       1560.000
# 2024-11-13                                    10115.0       1560.000
# 2024-11-14                                     8800.0       1560.000
# ...                                               ...            ...
# 2025-01-28                                     9900.0       2039.645
# 2025-01-29                                     9900.0       2040.000
# 2025-01-30                                     9900.0       1800.000
# 2025-01-31                                     9900.0       1800.000
# 2025-02-03                                     9900.0       1800.000
#
#             Cbz Holdings Limited  Cfi Holdings Limited  \
# 2024-11-10             1499.0000                372.25
# 2024-11-11             1499.0000                372.25
# 2024-11-12             1398.6137                428.05
# 2024-11-13             1399.5131                428.05
# 2024-11-14             1399.5131                492.25
# ...                          ...                   ...
# 2025-01-28              840.0000                418.00
# 2025-01-29              840.0000                480.00
# 2025-01-30              840.0000                480.00
# 2025-01-31              840.0000                480.00
# 2025-02-03              840.0000                480.00
#
#             Dairibord Holdings Limited  Delta Corporation Limited  \
# 2024-11-10                    196.2500                  1942.6048
# 2024-11-11                    196.2500                  1942.6048
# 2024-11-12                    196.2500                  1942.9869
# 2024-11-13                    196.0000                  1912.9224
# 2024-11-14                    196.0833                  1913.1514
# ...                                ...                        ...
# 2025-01-28                    195.5000                  1350.4617
# 2025-01-29                    195.5000                  1341.9328
# 2025-01-30                    195.5000                  1334.7743
# 2025-01-31                    195.5000                  1314.8209
# 2025-02-03                    195.5000                  1296.9277
#
#             Ecocash Holdings Zimbabwe Limited  ...  Turnall Holdings Limited  \
# 2024-11-10                            40.0500  ...                      6.50
# 2024-11-11                            40.0500  ...                      6.50
# 2024-11-12                            38.5197  ...                      6.50
# 2024-11-13                            39.9615  ...                      6.50
# 2024-11-14                            38.1814  ...                      6.12
# ...                                       ...  ...                       ...
# 2025-01-28                            29.0000  ...                      5.50
# 2025-01-29                            29.0000  ...                      5.50
# 2025-01-30                            29.0000  ...                      5.50
# 2025-01-31                            29.0000  ...                      5.50
# 2025-02-03                            29.7500  ...                      5.50
#
#             Unifreight Africa Limited  Willdale Limited  \
# 2024-11-10                     249.95            5.4380
# 2024-11-11                     249.95            5.4380
# 2024-11-12                     249.95            5.3735
# 2024-11-13                     250.00            5.3735
# 2024-11-14                     250.00            5.2000
# ...                               ...               ...
# 2025-01-28                     212.00            5.9500
# 2025-01-29                     212.00            5.9500
# 2025-01-30                     212.00            5.5000
# 2025-01-31                     212.00            5.5000
# 2025-02-03                     212.00            5.5000
#
#             Zb Financial Holdings Limited  Zeco Holdings Limited  \
# 2024-11-10                       750.0000                 0.0018
# 2024-11-11                       750.0000                 0.0018
# 2024-11-12                       750.0000                 0.0018
# 2024-11-13                       730.0000                 0.0018
# 2024-11-14                       730.0000                 0.0018
# ...                                   ...                    ...
# 2025-01-28                       480.0000                 0.0018
# 2025-01-29                       480.0000                 0.0018
# 2025-01-30                       412.7273                 0.0018
# 2025-01-31                       470.0000                 0.0018
# 2025-02-03                       470.0000                 0.0018
#
#             Zimbabwe Newspapers (1980) Limited  Zimre Holdings Limited  \
# 2024-11-10                                   6                 55.2500
# 2024-11-11                                   6                 55.2500
# 2024-11-12                                   6                 55.2445
# 2024-11-13                                   6                 55.2500
# 2024-11-14                                   6                 55.2500
# ...                                        ...                     ...
# 2025-01-28                                  15                 17.0000
# 2025-01-29                                  15                 17.0000
# 2025-01-30                                  15                 17.0000
# 2025-01-31                                  15                 17.0000
# 2025-02-03                                  15                 19.5500
#
#             Bridgefort Capital Limited  Bridgefort Capital Limited Class B  \
# 2024-11-10                         1.5                                2.64
# 2024-11-11                         1.5                                2.64
# 2024-11-12                         1.5                                2.64
# 2024-11-13                         1.5                                2.64
# 2024-11-14                         1.5                                2.64
# ...                                ...                                 ...
# 2025-01-28                         NaN                                 NaN
# 2025-01-29                         NaN                                 NaN
# 2025-01-30                         NaN                                 NaN
# 2025-01-31                         NaN                                 NaN
# 2025-02-03                         NaN                                 NaN
#
#             Meikles Limited
# 2024-11-10           429.95
# 2024-11-11           429.95
# 2024-11-12           429.95
# 2024-11-13           441.98
# 2024-11-14           420.00
# ...                     ...
# 2025-01-28              NaN
# 2025-01-29              NaN
# 2025-01-30              NaN
# 2025-01-31              NaN
# 2025-02-03              NaN
#
# [62 rows x 40 columns]

# %%
# import pandas as pd

# Load JSON data into a DataFrame
# def load_json_data(file_path: str) -> pd.DataFrame:
#     return pd.read_json(file_path, orient='split')

# # Example usage
# open_price_df = load_json_data('open_price.json')
# close_price_df = load_json_data('close_price.json')
# vol_traded_df = load_json_data('vol_traded.json')

# # Display the DataFrames
# open_price_df.head()
# close_price_df.head()
# vol_traded_df.head()

# %%
#schedule.every(1).day.do(update_data)

#while True:
   #schedule.run_pending()
   #time.sleep(1)

   #print('jobs:', len(schedule.get_jobs()))
